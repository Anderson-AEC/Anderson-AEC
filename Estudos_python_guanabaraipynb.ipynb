# %% [markdown]
# <a href="https://colab.research.google.com/github/Anderson-AEC/Anderson-AEC/blob/main/Estudos_python_guanabaraipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello word!")
# Out:
# hello word!

# %%
nome= input('Qual o seu nome? ')
print('Olá', nome)
idade= int(input('Qual a sua idade? '))
print('Você tem', idade, 'anos')
peso= float(input('Qual o seu peso? '))
print('Você pesa', peso, 'kg')
altura= float(input('Qual a sua altura? '))
print('Você mede', altura, 'm')
peso_ideal= (72.7*altura) - 58
print('Seu peso ideal é', peso_ideal, 'kg')
# Out:
# Qual o seu nome?Anderson
# Olá Anderson
# Qual a sua idade?35
# Você tem 35 anos
# Qual o seu peso?150
# Você pesa 150 kg
# Qual a sua altura?1.75
# Você mede 1.75 m
# Seu peso ideal é 69.22500000000001 kg
