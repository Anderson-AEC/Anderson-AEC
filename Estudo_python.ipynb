# %% [markdown]
# <a href="https://colab.research.google.com/github/Anderson-AEC/Anderson-AEC/blob/main/Estudo_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome=input('Qual seu nome? ')
print('Ola', nome)
# Out:
# Qual seu nome? Anderson
# Ola Anderson
